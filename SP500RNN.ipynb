# %% [markdown]
# ### Loading and preparing the data

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b18d2de5-6e03-4124-969e-5fcb55c13b8e" name="files[]" multiple disabled />
#      <output id="result-b18d2de5-6e03-4124-969e-5fcb55c13b8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_stocks.csv to data_stocks.csv

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['data_stocks.csv']))
df = df.drop('DATE', axis = 1 )

# %%
df.head()
# Out:
#        SP500  NASDAQ.AAL  NASDAQ.AAPL  ...  NYSE.YUM  NYSE.ZBH  NYSE.ZTS
# 0  2363.6101     42.3300     143.6800  ...     63.86   122.000    53.350
# 1  2364.1001     42.3600     143.7000  ...     63.74   121.770    53.350
# 2  2362.6799     42.3100     143.6901  ...     63.75   121.700    53.365
# 3  2364.3101     42.3700     143.6400  ...     63.88   121.700    53.380
# 4  2364.8501     42.5378     143.6600  ...     63.91   121.695    53.240
#
# [5 rows x 501 columns]

# %% [markdown]
# ### Examining autocorrelations

# %%
sp = df['SP500']
sp.head(10)
# Out:
# 0    2363.6101
# 1    2364.1001
# 2    2362.6799
# 3    2364.3101
# 4    2364.8501
# 5    2365.6201
# 6    2365.2000
# 7    2365.2900
# 8    2364.3201
# 9    2364.6399
# Name: SP500, dtype: float64

# %% [markdown]
# ### Autocorrelations

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(sp)
pyplot.show()

# %% [markdown]
# ### Partial autocorrelations

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(sp)
pyplot.show()
